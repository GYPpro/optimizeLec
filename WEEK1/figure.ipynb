# %%
import matplotlib.pyplot as plt
import math as mt
import pandas as pd
import numpy as np

# %%
arr = np.linspace(1,100,100);
# print(arr)|
t = 100
f = [1,1]
len = 2
while t > 0:
    t = t-1
    f.append(f[len -1] + f[len -2])
    len = len+1
# print (f)
t = [f[i]/f[i+1] for i in range(1,101)]
plt.plot(arr,t)

# %%
arr = np.linspace(-1000,10000,500);
y = [(x-0.3) ** 2 + min((1/(x-0.3))**(10**5),0.001) for x in arr]
plt.plot(arr,y)
